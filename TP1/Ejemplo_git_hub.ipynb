# %% [markdown]
# <a href="https://colab.research.google.com/github/uwuchiquito/Entregas/blob/main/TP1/Ejemplo_git_hub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # "EJEMPLO PARA GIT HUB"

# %% [markdown]
# > Añadir blockquote![git.jpg](data:image/jpeg;base64,...)
